# %%
import numpy as np
import energy_ml.data.loader as loader
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import energy_ml.analysis.Basic_stats_scripts as Analysis
import energy_ml.analysis.plotting as pltting
from sklearn.ensemble import RandomForestRegressor

# %%
#I can type here and see what might work?

# %%
Data_frame = loader.load_energy_data("C:/Users/gregr/Current_coding_projects/Git_repo_testing/Training-energy-demand-forecasting-ml/data/raw/household_power_consumption.txt", ';')
df, issues = loader.Data_formatting_clean_reassemble(Data_frame)
print(df.info())
# Out:
# C:\Users\gregr\Current_coding_projects\Git_repo_testing\Training-energy-demand-forecasting-ml\src\energy_ml\data\loader.py:13: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep=sepa)
#  Top 3 rows of data input          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# ...

# %%
# I think that this is working and seems to save the output

# %%
Data_fitting = 'Global_active_power'


Features = ['rolling_24_std','rolling_24_mean','lag_1','lag_24']

Analysis.analyse_the_best_features_random_forest(Features, df, Data_fitting)
# Out:
# 1/15 -> ('rolling_24_std',)
# function print, the metric: {'Train MAE': 0.6578490327214668, 'Train RMSE': np.float64(0.8781240387372137), 'Test MAE': 0.5960411455204422, 'Test RMSE': np.float64(0.7638125531164932)}
# 2/15 -> ('rolling_24_mean',)
# problem with the called data. Try: hour, dayofweek, month, day, year, quarter, lag_1, lag_24, rolling_24_mean, rolling_24_std
# function print, the metric: {'Train MAE': 0.30975354324036714, 'Train RMSE': np.float64(0.5695202670187272), 'Test MAE': 0.28477024676933976, 'Test RMSE': np.float64(0.49793509287636384)}
# 3/15 -> ('lag_1',)
# problem with the called data. Try: hour, dayofweek, month, day, year, quarter, lag_1, lag_24, rolling_24_mean, rolling_24_std
# function print, the metric: {'Train MAE': 0.10224999128057843, 'Train RMSE': np.float64(0.2754028712179866), 'Test MAE': 0.08512513583481554, 'Test RMSE': np.float64(0.22067216682623655)}
# 4/15 -> ('lag_24',)
# ...

# %%
# Okay the notebook seems to work well... or at least copying and paasting material in is fine, need to try code development?

# I think I want to try to add some machine learning functions

# I should be able to do this in the notebook. 

# After adding this, I think I want to try a new version or at least some new version of data extraction and analysis. 

# I want to dynamically load data, something that loads data (optional to prevent some blocking) and then perform analysis

# Maybe something like download weather data for the previous day at a location, then predict the next day? 

# continuous updateable file, with load and read functions then analysis.
